# %%
# %load_ext rpy2.ipython
import numpy as np
import pandas as pd
import json
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import random


parametros = {"perfil_1":{"media_1":50,"desviacion_1":1,
                         "media_2":50,"desviacion_2":1,
                         "media_3":50,"desviacion_3":1},
             "perfil_2":{"media_1":10,"desviacion_1":1,
                         "media_2":10,"desviacion_2":1,
                         "media_3":10,"desviacion_3":1},
              "perfil_3":{"media_1":90,"desviacion_1":1,
                         "media_2":90,"desviacion_2":1,
                         "media_3":90,"desviacion_3":1}
             }
perfiles = ["perfil_1","perfil_2","perfil_3"]
observaciones = []
perfil_obs = []
for idx in range(1000):
    perfil = random.sample(perfiles,1)
    perfil = perfil[0]
    perfil_obs.append(perfil)
    obs_1 = random.normalvariate(parametros[perfil]["media_1"], parametros[perfil]["desviacion_1"])
    obs_2 = random.normalvariate(parametros[perfil]["media_2"], parametros[perfil]["desviacion_2"])
    obs_3 = random.normalvariate(parametros[perfil]["media_3"], parametros[perfil]["desviacion_3"])

    observaciones.append([obs_1, obs_2, obs_3])

def conecta_vecinos_graph(vecinos,observaciones):
    from sklearn.neighbors import NearestNeighbors
    import numpy as np

    X = np.array(observaciones)
    nbrs = NearestNeighbors(n_neighbors=vecinos, algorithm='ball_tree').fit(X)
    distances, indices = nbrs.kneighbors(X)

    vecinos_cercanos_graph = {}
    for index in indices:
        vecinos_cercanos_graph[index[0]] = set(index[1:])

    return vecinos_cercanos_graph

graph_vecinos = conecta_vecinos_graph(5,observaciones)

def bfs(grafo, nodo0):
    visitado, cola = set(), [nodo0]
    while cola:
        vertex = cola.pop(0)
        if vertex not in visitado:
            visitado.add(vertex)
            if vertex not in grafo:
                grafo[vertex] = set()
                #print 'Tupla:', vertex, ',', len(grafo[vertex]), ',', len(visitado)
            cola.extend(grafo[vertex] - visitado)

    return visitado

def searchKNN(grafo, nodo0):
    klts = []
    faltantes = grafo
    visitados = bfs(grafo, nodo0)
    c=0
    while len(faltantes)>0:
        kls = {}

        for visitado in list(visitados):
            if grafo.has_key(visitado):
                kls[visitado]= grafo[visitado] #guardamos en el cluster
                del faltantes[visitado]
                visitados.remove(visitado)


        klts.append(kls)


        if len(faltantes) >0:
            #print faltantes.keys()[0]
            #print faltantes
            visitados = bfs(faltantes, faltantes.keys()[0])
    return klts

def create_clusterDict(cluster):
    return dict([('cluster_{0}'.format(clu),clusters[clu]) for clu in range(len(clusters))])

def get_joins(dClustered):
    from itertools import chain
    sso = dClustered.items()
    _presup = [[set(sso[idk][1].keys()).intersection(set(sso[idj][1].keys()))for idj in xrange(idk+1,len(sso)) if idj != idk ] for idk, k in enumerate(sso)]    
    return dict([('cluster_{0}'.format(idp),p) for idp, p in enumerate( list(chain(*_presup))) if p!=set()])
    

def create_adMatrix(clustr_dict):
    ##Numero de clusters, estos vienen en formato de diccionario
    num_clusters = len(clustr_dict)
    
    ##Creamos una matriz de adyacencia con puros ceros
    matrix_inicial = np.zeros((num_clusters, num_clusters))
    names = [cluster for cluster in clustr_dict.keys()]
    matrix_distances = pd.DataFrame(matrix_inicial, index=names, columns=names)
    #matrix_distances
    
    ##Hacemos una comparacion entre cada cluster, para sacar el numero de elementos que comparten, quiza no es lo más
    ##eficiente pero es muy sencillo

    for idx_1 in clustr_dict.keys():
        for idx_2 in clustr_dict.keys():
            if idx_1 != idx_2:
                #Elementos en cada cluster
                elementos_uno = float(len(clustr_dict[idx_1]))
                elementos_dos = float(len(clustr_dict[idx_2]))

                #El cluster con el menor numero de elementos
                minimo_elementos = min(elementos_uno, elementos_dos)

                #cuantos elementos comparten cada cluster
                elementos_compartidos = len(list(set(clustr_dict[idx_1]).intersection(clustr_dict[idx_2])))

                #Asignamos a la matriz la distancia como 1 - num_elemntos_comp / minim_elementos
                matrix_distances[idx_1][idx_2] = 1- (elementos_compartidos/minimo_elementos) 
                #matrix_distances[idx_1][idx_2] = elementos_compartidos
    
    return matrix_distances

# %%
graph_vecinos = conecta_vecinos_graph(8, observaciones)
clusters=searchKNN(graph_vecinos, 0)
cdict = create_clusterDict(clusters)
joind = get_joins(cdict)
adyM = create_adMatrix(joind)
adyM
# Out:
#              cluster_119  cluster_108  cluster_10  cluster_154  cluster_85  \
# cluster_119          0.0     1.000000         1.0          1.0         1.0
# cluster_108          1.0     0.000000         1.0          1.0         1.0
# cluster_10           1.0     1.000000         0.0          1.0         1.0
# cluster_154          1.0     1.000000         1.0          0.0         1.0
# cluster_85           1.0     1.000000         1.0          1.0         0.0
# cluster_150          1.0     1.000000         1.0          1.0         1.0
# cluster_43           1.0     0.857143         1.0          1.0         1.0
# cluster_130          1.0     1.000000         1.0          1.0         1.0
# cluster_27           1.0     1.000000         1.0          1.0         1.0
# cluster_59           1.0     1.000000         1.0          1.0         1.0
# cluster_98           1.0     1.000000         1.0          1.0         1.0
# cluster_131          1.0     1.000000         1.0          1.0         1.0
# cluster_70           1.0     1.000000         1.0          1.0         1.0
# cluster_39           1.0     0.000000         1.0          1.0         1.0
# cluster_134          1.0     1.000000         1.0          1.0         1.0
# cluster_132          1.0     1.000000         1.0          1.0         1.0
# cluster_136          1.0     1.000000         1.0          1.0         1.0
# cluster_53           1.0     1.000000         1.0          1.0         1.0
#
#              cluster_150  cluster_43  cluster_130  cluster_27  cluster_59  \
# cluster_119          1.0    1.000000          1.0         1.0    1.000000
# cluster_108          1.0    0.857143          1.0         1.0    1.000000
# cluster_10           1.0    1.000000          1.0         1.0    1.000000
# cluster_154          1.0    1.000000          1.0         1.0    1.000000
# cluster_85           1.0    1.000000          1.0         1.0    1.000000
# cluster_150          0.0    1.000000          1.0         1.0    1.000000
# cluster_43           1.0    0.000000          1.0         1.0    1.000000
# cluster_130          1.0    1.000000          0.0         1.0    1.000000
# cluster_27           1.0    1.000000          1.0         0.0    1.000000
# cluster_59           1.0    1.000000          1.0         1.0    0.000000
# cluster_98           1.0    1.000000          1.0         1.0    0.857143
# cluster_131          1.0    1.000000          1.0         1.0    1.000000
# cluster_70           1.0    1.000000          1.0         1.0    1.000000
# cluster_39           1.0    0.000000          1.0         1.0    1.000000
# cluster_134          1.0    1.000000          1.0         1.0    1.000000
# cluster_132          1.0    1.000000          1.0         1.0    1.000000
# cluster_136          1.0    1.000000          1.0         1.0    1.000000
# cluster_53           1.0    1.000000          1.0         1.0    0.000000
#
#              cluster_98  cluster_131  cluster_70  cluster_39  cluster_134  \
# cluster_119    1.000000          1.0         1.0         1.0          1.0
# cluster_108    1.000000          1.0         1.0         0.0          1.0
# cluster_10     1.000000          1.0         1.0         1.0          1.0
# cluster_154    1.000000          1.0         1.0         1.0          1.0
# cluster_85     1.000000          1.0         1.0         1.0          1.0
# cluster_150    1.000000          1.0         1.0         1.0          1.0
# cluster_43     1.000000          1.0         1.0         0.0          1.0
# cluster_130    1.000000          1.0         1.0         1.0          1.0
# cluster_27     1.000000          1.0         1.0         1.0          1.0
# cluster_59     0.857143          1.0         1.0         1.0          1.0
# cluster_98     0.000000          1.0         1.0         1.0          1.0
# cluster_131    1.000000          0.0         1.0         1.0          1.0
# cluster_70     1.000000          1.0         0.0         1.0          1.0
# cluster_39     1.000000          1.0         1.0         0.0          1.0
# cluster_134    1.000000          1.0         1.0         1.0          0.0
# cluster_132    1.000000          1.0         1.0         1.0          1.0
# cluster_136    1.000000          1.0         1.0         1.0          1.0
# cluster_53     0.000000          1.0         1.0         1.0          1.0
#
#              cluster_132  cluster_136  cluster_53
# cluster_119          1.0          1.0         1.0
# cluster_108          1.0          1.0         1.0
# cluster_10           1.0          1.0         1.0
# cluster_154          1.0          1.0         1.0
# cluster_85           1.0          1.0         1.0
# cluster_150          1.0          1.0         1.0
# cluster_43           1.0          1.0         1.0
# cluster_130          1.0          1.0         1.0
# cluster_27           1.0          1.0         1.0
# cluster_59           1.0          1.0         0.0
# cluster_98           1.0          1.0         0.0
# cluster_131          1.0          1.0         1.0
# cluster_70           1.0          1.0         1.0
# cluster_39           1.0          1.0         1.0
# cluster_134          1.0          1.0         1.0
# cluster_132          0.0          1.0         1.0
# cluster_136          1.0          0.0         1.0
# cluster_53           1.0          1.0         0.0

# %%
#tabler = np.array([])
#for i in range(adyM.shape[0]):
#    for j in xrange(i+1, adyM.shape[0]):
#        tabler.append((i,j,np.array(adyM)[i,j]))

#print adyM
import pandas as pd
import re
adf= pd.DataFrame(adyM)
adf['nodoOrigen']= adf.index
adf_melt= pd.melt(adf,id_vars=['nodoOrigen'],value_vars=list(adf.columns.values)[:-1],var_name='nodoDestino', value_name='valor')
adf_melt= adf_melt[0:225]

#adf_melt['val'] = [str(v) for v in adf_melt['valor']]

adf_melt['orig']= [int(re.sub('^.*_','',n)) for n in adf_melt['nodoOrigen']]
adf_melt['dest']= [int(re.sub('^.*_','',n)) for n in adf_melt['nodoDestino']]
adf_proc= adf_melt[['orig','dest','valor']]

#print(adf_proc)
#adf.columns
#adyM.columns
#pandas.melt(adyM,id_vars=)
#pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])

# %%
tbl = np.array(adf_proc)
colnames = adf_proc.columns
#np.array(adf_proc)

# %%
linksJSON = json.dumps([{colnames[0]:idx[0], colnames[1]:idx[1],colnames[2]:idx[2]} for idx in tbl])
linksJSON2 = json.dumps([{'source':idx[0], 'target':idx[1],'value':idx[2]} for idx in tbl])
nodesJSON = json.dumps([{'color':idx,'group':tbl[idx,2],'name':idx,'tootip':idx,} for idx in range(adf_proc.shape[0])])
nodesJSON2 = json.dumps([{'group':idx+1,'size':tbl[idx,2],'name':idx} for idx in range(adf_proc.shape[0])])
graphJSON = "{{'nodes': {0}, 'links': {1} }}".format(nodesJSON, linksJSON)
graphJSON2 = {'nodes': nodesJSON2, 'links': linksJSON2 }

# %%
graphJSON2
# Out:
# {'links': '[{"source": 119.0, "target": 119.0, "value": 0.0}, {"source": 108.0, "target": 119.0, "value": 1.0}, {"source": 10.0, "target": 119.0, "value": 1.0}, {"source": 154.0, "target": 119.0, "value": 1.0}, {"source": 85.0, "target": 119.0, "value": 1.0}, {"source": 150.0, "target": 119.0, "value": 1.0}, {"source": 43.0, "target": 119.0, "value": 1.0}, {"source": 130.0, "target": 119.0, "value": 1.0}, {"source": 27.0, "target": 119.0, "value": 1.0}, {"source": 59.0, "target": 119.0, "value": 1.0}, {"source": 98.0, "target": 119.0, "value": 1.0}, {"source": 131.0, "target": 119.0, "value": 1.0}, {"source": 70.0, "target": 119.0, "value": 1.0}, {"source": 39.0, "target": 119.0, "value": 1.0}, {"source": 134.0, "target": 119.0, "value": 1.0}, {"source": 132.0, "target": 119.0, "value": 1.0}, {"source": 136.0, "target": 119.0, "value": 1.0}, {"source": 53.0, "target": 119.0, "value": 1.0}, {"source": 119.0, "target": 108.0, "value": 1.0}, {"source": 108.0, "target": 108.0, "value": 0.0}, {"source": 10.0, "target": 108.0, "value": 1.0}, {"source": 154.0, "target": 108.0, "value": 1.0}, {"source": 85.0, "target": 108.0, "value": 1.0}, {"source": 150.0, "target": 108.0, "value": 1.0}, {"source": 43.0, "target": 108.0, "value": 0.85714285714285721}, {"source": 130.0, "target": 108.0, "value": 1.0}, {"source": 27.0, "target": 108.0, "value": 1.0}, {"source": 59.0, "target": 108.0, "value": 1.0}, {"source": 98.0, "target": 108.0, "value": 1.0}, {"source": 131.0, "target": 108.0, "value": 1.0}, {"source": 70.0, "target": 108.0, "value": 1.0}, {"source": 39.0, "target": 108.0, "value": 0.0}, {"source": 134.0, "target": 108.0, "value": 1.0}, {"source": 132.0, "target": 108.0, "value": 1.0}, {"source": 136.0, "target": 108.0, "value": 1.0}, {"source": 53.0, "target": 108.0, "value": 1.0}, {"source": 119.0, "target": 10.0, "value": 1.0}, {"source": 108.0, "target": 10.0, "value": 1.0}, {"source": 10.0, "target": 10.0, "value": 0.0}, {"source": 154.0, "target": 10.0, "value": 1.0}, {"source": 85.0, "target": 10.0, "value": 1.0}, {"source": 150.0, "target": 10.0, "value": 1.0}, {"source": 43.0, "target": 10.0, "value": 1.0}, {"source": 130.0, "target": 10.0, "value": 1.0}, {"source": 27.0, "target": 10.0, "value": 1.0}, {"source": 59.0, "target": 10.0, "value": 1.0}, {"source": 98.0, "target": 10.0, "value": 1.0}, {"source": 131.0, "target": 10.0, "value": 1.0}, {"source": 70.0, "target": 10.0, "value": 1.0}, {"source": 39.0, "target": 10.0, "value": 1.0}, {"source": 134.0, "target": 10.0, "value": 1.0}, {"source": 132.0, "target": 10.0, "value": 1.0}, {"source": 136.0, "target": 10.0, "value": 1.0}, {"source": 53.0, "target": 10.0, "value": 1.0}, {"source": 119.0, "target": 154.0, "value": 1.0}, {"source": 108.0, "target": 154.0, "value": 1.0}, {"source": 10.0, "target": 154.0, "value": 1.0}, {"source": 154.0, "target": 154.0, "value": 0.0}, {"source": 85.0, "target": 154.0, "value": 1.0}, {"source": 150.0, "target": 154.0, "value": 1.0}, {"source": 43.0, "target": 154.0, "value": 1.0}, {"source": 130.0, "target": 154.0, "value": 1.0}, {"source": 27.0, "target": 154.0, "value": 1.0}, {"source": 59.0, "target": 154.0, "value": 1.0}, {"source": 98.0, "target": 154.0, "value": 1.0}, {"source": 131.0, "target": 154.0, "value": 1.0}, {"source": 70.0, "target": 154.0, "value": 1.0}, {"source": 39.0, "target": 154.0, "value": 1.0}, {"source": 134.0, "target": 154.0, "value": 1.0}, {"source": 132.0, "target": 154.0, "value": 1.0}, {"source": 136.0, "target": 154.0, "value": 1.0}, {"source": 53.0, "target": 154.0, "value": 1.0}, {"source": 119.0, "target": 85.0, "value": 1.0}, {"source": 108.0, "target": 85.0, "value": 1.0}, {"source": 10.0, "target": 85.0, "value": 1.0}, {"source": 154.0, "target": 85.0, "value": 1.0}, {"source": 85.0, "target": 85.0, "value": 0.0}, {"source": 150.0, "target": 85.0, "value": 1.0}, {"source": 43.0, "target": 85.0, "value": 1.0}, {"source": 130.0, "target": 85.0, "value": 1.0}, {"source": 27.0, "target": 85.0, "val ...
#  'nodes': '[{"group": 1, "name": 0, "size": 0.0}, {"group": 2, "name": 1, "size": 1.0}, {"group": 3, "name": 2, "size": 1.0}, {"group": 4, "name": 3, "size": 1.0}, {"group": 5, "name": 4, "size": 1.0}, {"group": 6, "name": 5, "size": 1.0}, {"group": 7, "name": 6, "size": 1.0}, {"group": 8, "name": 7, "size": 1.0}, {"group": 9, "name": 8, "size": 1.0}, {"group": 10, "name": 9, "size": 1.0}, {"group": 11, "name": 10, "size": 1.0}, {"group": 12, "name": 11, "size": 1.0}, {"group": 13, "name": 12, "size": 1.0}, {"group": 14, "name": 13, "size": 1.0}, {"group": 15, "name": 14, "size": 1.0}, {"group": 16, "name": 15, "size": 1.0}, {"group": 17, "name": 16, "size": 1.0}, {"group": 18, "name": 17, "size": 1.0}, {"group": 19, "name": 18, "size": 1.0}, {"group": 20, "name": 19, "size": 0.0}, {"group": 21, "name": 20, "size": 1.0}, {"group": 22, "name": 21, "size": 1.0}, {"group": 23, "name": 22, "size": 1.0}, {"group": 24, "name": 23, "size": 1.0}, {"group": 25, "name": 24, "size": 0.85714285714285721}, {"group": 26, "name": 25, "size": 1.0}, {"group": 27, "name": 26, "size": 1.0}, {"group": 28, "name": 27, "size": 1.0}, {"group": 29, "name": 28, "size": 1.0}, {"group": 30, "name": 29, "size": 1.0}, {"group": 31, "name": 30, "size": 1.0}, {"group": 32, "name": 31, "size": 0.0}, {"group": 33, "name": 32, "size": 1.0}, {"group": 34, "name": 33, "size": 1.0}, {"group": 35, "name": 34, "size": 1.0}, {"group": 36, "name": 35, "size": 1.0}, {"group": 37, "name": 36, "size": 1.0}, {"group": 38, "name": 37, "size": 1.0}, {"group": 39, "name": 38, "size": 0.0}, {"group": 40, "name": 39, "size": 1.0}, {"group": 41, "name": 40, "size": 1.0}, {"group": 42, "name": 41, "size": 1.0}, {"group": 43, "name": 42, "size": 1.0}, {"group": 44, "name": 43, "size": 1.0}, {"group": 45, "name": 44, "size": 1.0}, {"group": 46, "name": 45, "size": 1.0}, {"group": 47, "name": 46, "size": 1.0}, {"group": 48, "name": 47, "size": 1.0}, {"group": 49, "name": 48, "size": 1.0}, {"group": 50, "name": 49, "size": 1.0}, {"group": 51, "name": 50, "size": 1.0}, {"group": 52, "name": 51, "size": 1.0}, {"group": 53, "name": 52, "size": 1.0}, {"group": 54, "name": 53, "size": 1.0}, {"group": 55, "name": 54, "size": 1.0}, {"group": 56, "name": 55, "size": 1.0}, {"group": 57, "name": 56, "size": 1.0}, {"group": 58, "name": 57, "size": 0.0}, {"group": 59, "name": 58, "size": 1.0}, {"group": 60, "name": 59, "size": 1.0}, {"group": 61, "name": 60, "size": 1.0}, {"group": 62, "name": 61, "size": 1.0}, {"group": 63, "name": 62, "size": 1.0}, {"group": 64, "name": 63, "size": 1.0}, {"group": 65, "name": 64, "size": 1.0}, {"group": 66, "name": 65, "size": 1.0}, {"group": 67, "name": 66, "size": 1.0}, {"group": 68, "name": 67, "size": 1.0}, {"group": 69, "name": 68, "size": 1.0}, {"group": 70, "name": 69, "size": 1.0}, {"group": 71, "name": 70, "size": 1.0}, {"group": 72, "name": 71, "size": 1.0}, {"group": 73, "name": 72, "size": 1.0}, {"group": 74, "name": 73, "size": 1.0}, {"group": 75, "name": 74, "size": 1.0}, {"group": 76, "name": 75, "size": 1.0}, {"group": 77, "name": 76, "size": 0.0}, {"group": 78, "name": 77, "size": 1.0}, {"group": 79, "name": 78, "size": 1.0}, {"group": 80, "name": 79, "size": 1.0}, {"group": 81, "name": 80, "size": 1.0}, {"group": 82, "name": 81, "size": 1.0}, {"group": 83, "name": 82, "size": 1.0}, {"group": 84, "name": 83, "size": 1.0}, {"group": 85, "name": 84, "size": 1.0}, {"group": 86, "name": 85, "size": 1.0}, {"group": 87, "name": 86, "size": 1.0}, {"group": 88, "name": 87, "size": 1.0}, {"group": 89, "name": 88, "size": 1.0}, {"group": 90, "name": 89, "size": 1.0}, {"group": 91, "name": 90, "size": 1.0}, {"group": 92, "name": 91, "size": 1.0}, {"group": 93, "name": 92, "size": 1.0}, {"group": 94, "name": 93, "size": 1.0}, {"group": 95, "name": 94, "size": 1.0}, {"group": 96, "name": 95, "size": 0.0}, {"group": 97, "name": 96, "size": 1.0}, {"group": 98, "name": 97, "size": 1.0}, {"group": 99, "name": 98, "size": 1.0}, {"group": 100, "name": 99, "siz ...

# %%
with open('data.json', 'w') as outfile:
    json.dump(graphJSON2, outfile)

# %%
# %R htmlFile <- readLines("www/index.html")
# %R graph_def_line <- which(grepl("graph =", htmlFile))
# %R -i graphJSON htmlFile[graph_def_line] <- sprintf("graph = %s;", graphJSON)
# %R writeLines(htmlFile, "www/index.html")

#%R browseURL("file:///media/sf_Dropbox/Cursos%20impartidos/TDA/ManifoldLearning/www/index.html")
# Out:
# Error in (function (file = "", n = NULL, text = NULL, prompt = "?", keep.source = getOption("keep.source"),  :
#   <text>:1:50: unexpected INCOMPLETE_STRING
# 1: withVisible({htmlFile[graph_def_line] <- sprintf("graph = %s
# 2: })
#                                                     ^
# /usr/local/lib/python2.7/dist-packages/rpy2/robjects/__init__.py:320: UserWarning: Error in (function (file = "", n = NULL, text = NULL, prompt = "?", keep.source = getOption("keep.source"),  :
#   <text>:1:50: unexpected INCOMPLETE_STRING
# 1: withVisible({htmlFile[graph_def_line] <- sprintf("graph = %s
# 2: })
#                                                     ^
#
#   p = _rparse(text=StrSexpVector((string,)))

# %%
import km
mapper = km.KeplerMapper(verbose=1)
mapper.visualize(graphJSON2, path_html="km_01.html", 
                 title="make_circles(n_samples=5000, noise=0.03, factor=0.3)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-15378b41c57b> in <module>()
#       2 mapper = km.KeplerMapper(verbose=1)
#       3 mapper.visualize(graphJSON2, path_html="km_01.html",
# ----> 4                  title="make_circles(n_samples=5000, noise=0.03, factor=0.3)")
#
# /home/sharop/notebooks/km.pyc in visualize(self, complex, color_function, path_html, title, graph_link_distance, graph_gravity, graph_charge, custom_tooltips, width_html, height_html, show_tooltips, show_title, show_meta)
#     254           json_s["nodes"].append({"name": str(k), "tooltip": tooltip_s, "group": 2 * int(np.log(len(complex["nodes"][k]))), "color": str(k.split("_")[0])})
#     255       else:
# --> 256         tooltip_s = "<h2>Cluster %s</h2>Contains %s members."%(k,len(complex["nodes"][k]))
#     257         json_s["nodes"].append({"name": str(k), "tooltip": tooltip_s, "group": 2 * int(np.log(len(complex["nodes"][k]))), "color": str(k.split("_")[0])})
#     258       k2e[k] = e
#
# TypeError: string indices must be integers, not str
